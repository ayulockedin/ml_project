# %% [markdown]
# <a href="https://colab.research.google.com/github/ayulockedin/ml_project/blob/main/mlops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ayulockedin/ml_project.git
# %cd ml_project
# Out:
# Cloning into 'ml_project'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (4/4), done.
# /content/ml_project/ml_project
